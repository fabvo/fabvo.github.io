# %%
import pandas as pd

# Load and inspect the uploaded CSV file
df = pd.read_csv('data\percentage-of-population-exposed-to-5.csv')
df
# Out:
#       Country:text  55 - 59 dB:number  60 - 64 dB:number  65 - 69 dB:number  \
# 0          Austria              21.33              14.44               8.11
# 1          Belgium              33.25              23.49              16.71
# 2         Bulgaria              22.21              34.39              21.13
# 3          Croatia              18.14              12.54               5.74
# 4           Cyprus              13.61              71.50               7.09
# 5   Czech Republic              33.45              20.72              11.44
# 6          Denmark              23.70              15.71              11.22
# 7          Estonia              18.09              22.82              15.30
# 8          Finland              17.38              13.78               6.51
# 9           France              10.61              10.22               7.90
# 10         Germany              10.39               6.77               4.78
# ...

# %%
# Display the first few rows and the basic information about the data
data_info = data.info()
data_head = data.head()

data_info, data_head
